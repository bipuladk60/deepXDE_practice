# %%
import deepxde as dde
import numpy as np
from deepxde.backend import tf
import matplotlib.pyplot as plt

# %%
def ide(x, y, int_mat):
    rhs = tf.matmul(int_mat, y)
    lhs1 = tf.gradients(y, x)[0]
    return (lhs1 + y)[: tf.size(rhs)] - rhs

# %%
def kernel(x, s):
    return np.exp(s - x)

# %%
def func(x):
    return np.exp(-x) * np.cosh(x)

# %%
geom = dde.geometry.TimeDomain(0, 5)
ic = dde.icbc.IC(geom, func, lambda _, on_initial: on_initial)

# %%
quad_deg = 20
data = dde.data.IDE(
    geom,
    ide,
    ic,
    quad_deg,
    kernel=kernel,
    num_domain=10,
    num_boundary=2,
    train_distribution="uniform",
)

# %%
layer_size = [1] + [20] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.nn.FNN(layer_size, activation, initializer)

# %%
model = dde.Model(data, net)
model.compile("L-BFGS")
model.train()
# Out:
# Compiling model...
# 'compile' took 0.091143 s
#
# Training model...
#
# 0         [2.11e-02, 1.00e+00]    [2.11e-02, 0.00e+00]    []
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/client/session.py:1402, in BaseSession._do_call(self, fn, *args)
#    1401 try:
# -> 1402   return fn(*args)
#    1403 except errors.OpError as e:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/client/session.py:1385, in BaseSession._do_run.<locals>._run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1384 self._extend_graph()
# -> 1385 return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1386                                 target_list, run_metadata)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/client/session.py:1478, in BaseSession._call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1476 def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1477                         run_metadata):
# -> 1478   return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1479                                           fetch_list, target_list,
#    1480                                           run_metadata)
#
# InvalidArgumentError: Matrix size-incompatible: In[0]: [12,252], In[1]: [253,1]
# 	 [[{{node MatMul_3}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[12], line 3
#       1 model = dde.Model(data, net)
#       2 model.compile("L-BFGS")
# ----> 3 model.train()
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/utils/internal.py:22, in timing.<locals>.wrapper(*args, **kwargs)
#      19 @wraps(f)
#      20 def wrapper(*args, **kwargs):
#      21     ts = timeit.default_timer()
# ---> 22     result = f(*args, **kwargs)
#      23     te = timeit.default_timer()
#      24     if config.rank == 0:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/model.py:640, in Model.train(self, iterations, batch_size, display_every, disregard_previous_best, callbacks, model_restore_path, model_save_path, epochs)
#     638 if optimizers.is_external_optimizer(self.opt_name):
#     639     if backend_name == "tensorflow.compat.v1":
# --> 640         self._train_tensorflow_compat_v1_scipy(display_every)
#     641     elif backend_name == "tensorflow":
#     642         self._train_tensorflow_tfp()
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/model.py:726, in Model._train_tensorflow_compat_v1_scipy(self, display_every)
#     724 if self.external_trainable_variables:
#     725     fetches += self.external_trainable_variables
# --> 726 self.train_step.minimize(
#     727     self.sess,
#     728     feed_dict=feed_dict,
#     729     fetches=fetches,
#     730     loss_callback=loss_callback,
#     731 )
#     732 self._test()
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/optimizers/tensorflow_compat_v1/scipy_optimizer.py:181, in ExternalOptimizerInterface.minimize(self, session, feed_dict, fetches, step_callback, loss_callback, **run_kwargs)
#     178 initial_packed_var_val = session.run(self._packed_var)
#     180 # Perform minimization.
# --> 181 packed_var_val = self._minimize(
#     182     initial_val=initial_packed_var_val,
#     183     loss_grad_func=loss_grad_func,
#     184     equality_funcs=equality_funcs,
#     185     equality_grad_funcs=equality_grad_funcs,
#     186     inequality_funcs=inequality_funcs,
#     187     inequality_grad_funcs=inequality_grad_funcs,
#     188     packed_bounds=self._packed_bounds,
#     189     step_callback=step_callback,
#     190     optimizer_kwargs=self.optimizer_kwargs,
#     191 )
#     192 var_vals = [
#     193     packed_var_val[packing_slice] for packing_slice in self._packing_slices
#     194 ]
#     196 # Set optimization variables to their new values.
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/optimizers/tensorflow_compat_v1/scipy_optimizer.py:382, in ScipyOptimizerInterface._minimize(self, initial_val, loss_grad_func, equality_funcs, equality_grad_funcs, inequality_funcs, inequality_grad_funcs, packed_bounds, step_callback, optimizer_kwargs)
#     378 minimize_kwargs.update(optimizer_kwargs)
#     380 import scipy.optimize  # pylint: disable=g-import-not-at-top
# --> 382 result = scipy.optimize.minimize(*minimize_args, **minimize_kwargs)
#     384 message_lines = [
#     385     "Optimization terminated with:",
#     386     "  Message: %s",
#     387     "  Objective function value: %f",
#     388 ]
#     389 message_args = [result.message, result.fun]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/scipy/optimize/_minimize.py:713, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#     712 elif meth == 'l-bfgs-b':
# --> 713     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     714                            callback=callback, **options)
#     715 elif meth == 'tnc':
#     716     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     717                         **options)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/scipy/optimize/_lbfgsb_py.py:309, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     306         iprint = disp
#     308 # _prepare_scalar_function can use bounds=None to represent no bounds
# --> 309 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     310                               bounds=bounds,
#     311                               finite_diff_rel_step=finite_diff_rel_step)
#     313 func_and_grad = sf.fun_and_grad
#     315 fortran_int = _lbfgsb.types.intvar.dtype
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/scipy/optimize/_optimize.py:402, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     398     bounds = (-np.inf, np.inf)
#     400 # ScalarFunction caches. Reuse of fun(x) during grad
#     401 # calculation reduces overall function evaluations.
# --> 402 sf = ScalarFunction(fun, x0, args, grad, hess,
#     403                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     405 return sf
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:166, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     163     self.f = fun_wrapped(self.x)
#     165 self._update_fun_impl = update_fun
# --> 166 self._update_fun()
#     168 # Gradient evaluation
#     169 if callable(grad):
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/scipy/optimize/_optimize.py:78, in MemoizeJac.__call__(self, x, *args)
#      76 def __call__(self, x, *args):
#      77     """ returns the function value """
# ---> 78     self._compute_if_needed(x, *args)
#      79     return self._value
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/scipy/optimize/_optimize.py:72, in MemoizeJac._compute_if_needed(self, x, *args)
#      70 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      71     self.x = np.asarray(x).copy()
# ---> 72     fg = self.fun(x, *args)
#      73     self.jac = fg[1]
#      74     self._value = fg[0]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/optimizers/tensorflow_compat_v1/scipy_optimizer.py:344, in ScipyOptimizerInterface._minimize.<locals>.loss_grad_func_wrapper(x)
#     342 def loss_grad_func_wrapper(x):
#     343     # SciPy's L-BFGS-B Fortran implementation requires gradients as doubles.
# --> 344     loss, gradient = loss_grad_func(x)
#     345     return loss, gradient.astype("float64")
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/optimizers/tensorflow_compat_v1/scipy_optimizer.py:268, in ExternalOptimizerInterface._make_eval_func.<locals>.eval_func(x)
#     265 augmented_feed_dict.update(feed_dict)
#     266 augmented_fetches = tensors + fetches
# --> 268 augmented_fetch_vals = session.run(
#     269     augmented_fetches, feed_dict=augmented_feed_dict
#     270 )
#     272 if callable(callback):
#     273     callback(*augmented_fetch_vals[num_tensors:])
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/client/session.py:972, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     969 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     971 try:
# --> 972   result = self._run(None, fetches, feed_dict, options_ptr,
#     973                      run_metadata_ptr)
#     974   if run_metadata:
#     975     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/client/session.py:1215, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1212 # We only want to really perform the run if fetches or targets are provided,
#    1213 # or if the call is a partial run that specifies feeds.
#    1214 if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1215   results = self._do_run(handle, final_targets, final_fetches,
#    1216                          feed_dict_tensor, options, run_metadata)
#    1217 else:
#    1218   results = []
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/client/session.py:1395, in BaseSession._do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1392   return self._call_tf_sessionprun(handle, feed_dict, fetch_list)
#    1394 if handle is None:
# -> 1395   return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1396                        run_metadata)
#    1397 else:
#    1398   return self._do_call(_prun_fn, handle, feeds, fetches)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/client/session.py:1421, in BaseSession._do_call(self, fn, *args)
#    1416 if 'only supports NHWC tensor format' in message:
#    1417   message += ('\nA possible workaround: Try disabling Grappler optimizer'
#    1418               '\nby modifying the config for creating the session eg.'
#    1419               '\nsession_config.graph_options.rewrite_options.'
#    1420               'disable_meta_optimizer = True')
# -> 1421 raise type(e)(node_def, op, message)
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'MatMul_3' defined at (most recent call last):
#     File "<frozen runpy>", line 198, in _run_module_as_main
#     File "<frozen runpy>", line 88, in _run_code
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/asyncio/events.py", line 80, in _run
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     File "/var/folders/6v/f_ghkc9j4rj89sspb4b9bpdh0000gn/T/ipykernel_71281/1650389351.py", line 2, in <module>
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/utils/internal.py", line 22, in wrapper
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/model.py", line 137, in compile
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/model.py", line 187, in _compile_tensorflow_compat_v1
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/model.py", line 172, in losses
#     File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/data/ide.py", line 68, in losses_test
#     File "/var/folders/6v/f_ghkc9j4rj89sspb4b9bpdh0000gn/T/ipykernel_71281/1045935923.py", line 2, in ide
# Node: 'MatMul_3'
# Matrix size-incompatible: In[0]: [12,252], In[1]: [253,1]
# 	 [[{{node MatMul_3}}]]
#
# Original stack trace for 'MatMul_3':
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/asyncio/events.py", line 80, in _run
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#   File "/var/folders/6v/f_ghkc9j4rj89sspb4b9bpdh0000gn/T/ipykernel_71281/1650389351.py", line 2, in <module>
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/utils/internal.py", line 22, in wrapper
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/model.py", line 137, in compile
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/model.py", line 187, in _compile_tensorflow_compat_v1
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/model.py", line 172, in losses
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/deepxde/data/ide.py", line 68, in losses_test
#   File "/var/folders/6v/f_ghkc9j4rj89sspb4b9bpdh0000gn/T/ipykernel_71281/1045935923.py", line 2, in ide
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/ops/weak_tensor_ops.py", line 142, in wrapper
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py", line 1260, in op_dispatch_handler
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/ops/math_ops.py", line 3842, in matmul
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/ops/gen_math_ops.py", line 6192, in mat_mul
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/framework/op_def_library.py", line 796, in _apply_op_helper
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/framework/ops.py", line 2652, in _create_op_internal
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/tensorflow/python/framework/ops.py", line 1160, in from_node_def

# %%
X = geom.uniform_points(100)
y_true = func(x)
y_pred = model.predict(x)
print("L2 relative error:", dde.metrics.l2_relative_error(y_true, y_pred))

# %%
plt.figure()
plt.plot(X, y_true, "-")
plt.plot(X, y_pred, "o")
plt.show()
np.savetxt("txt.dat", np.hstack((X, y_true, y_pred)))
